# %%
# !apt-get update -qq
# !apt-get install -y openjdk-17-jdk-headless -qq
# !pip install -q pyspark
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %%
# !java -version
# Out:
# openjdk version "17.0.19" 2026-04-21
# OpenJDK Runtime Environment (build 17.0.19+10-1-22.04.2-Ubuntu)
# OpenJDK 64-Bit Server VM (build 17.0.19+10-1-22.04.2-Ubuntu, mixed mode, sharing)

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
spark = SparkSession.builder \
    .master("local[*]") \
    .appName("Week6 Spark Assignment") \
    .getOrCreate()

# %%
print(spark.version)
# Out:
# 4.0.3

# %% [markdown]
# **READ CSV FILE **

# %%
df = spark.read.csv(
    "sales_dataset.csv",
    header=True,
    inferSchema=True
)

df.show()
# Out:
# +-------+----------------+------+----------------+-----------+-----+---+------------+-----+--------+------------------+--------+---------+----------------+
# |user_id|transaction_date|region|product_category|sale_amount| city|age|subscription|price|store_id|             email|username|   status|   raw_timestamp|
# +-------+----------------+------+----------------+-----------+-----+---+------------+-----+--------+------------------+--------+---------+----------------+
# |   1001|      01-01-2025|  West|     Electronics|        100|Delhi| 18|     Premium| NULL|    S101|              NULL|    NULL|     NULL|01-01-2025 10:00|
# |   1002|      02-01-2025|  West|       Furniture|        105|Delhi| 19|       Basic|  105|    S101|user1002@gmail.com|user1002|Completed|02-01-2025 10:01|
# |   1003|      03-01-2025|  West|        Clothing|        110|Delhi| 20|     Premium|  110|    S101|user1003@gmail.com|user1003|Completed|03-01-2025 10:02|
# |   1004|      04-01-2025|  West|         Grocery|        115|Delhi| 21|       Basic|  115|    S101|user1004@gmail.com|user1004|Completed|04-01-2025 10:03|
# |   1005|      05-01-2025|  West|     Electronics|        120|Delhi| 22|     Premium|  120|    S101|user1005@gmail.com|user1005|Completed|05-01-2025 10:04|
# |   1006|      06-01-2025|  West|       Furniture|        125|Delhi| 23|       Basic|  125|    S101|user1006@gmail.com|user1006|Completed|06-01-2025 10:05|
# |   1007|      07-01-2025|  West|        Clothing|        130|Delhi| 24|     Premium|  130|    S101|user1007@gmail.com|user1007|Completed|07-01-2025 10:06|
# |   1008|      08-01-2025|  West|         Grocery|        135|Delhi| 25|       Basic|  135|    S101|user1008@gmail.com|user1008|Completed|08-01-2025 10:07|
# |   1009|      09-01-2025|  West|     Electronics|        140|Delhi| 26|     Premium|  140|    S101|user1009@gmail.com|user1009|Completed|09-01-2025 10:08|
# |   1010|      10-01-2025|  West|       Furniture|        145|Delhi| 27|       Basic|  145|    S101|user1010@gmail.com|user1010|Completed|10-01-2025 10:09|
# |   1011|      11-01-2025|  West|        Clothing|        150|Delhi| 28|     Premium|  150|    S101|user1011@gmail.com|user1011|Completed|11-01-2025 10:10|
# |   1012|      12-01-2025|  West|         Grocery|        155|Delhi| 29|       Basic|  155|    S101|user1012@gmail.com|user1012|Completed|12-01-2025 10:11|
# |   1013|      13-01-2025|  West|     Electronics|        160|Delhi| 30|     Premium|  160|    S101|user1013@gmail.com|user1013|Completed|13-01-2025 10:12|
# |   1014|      14-01-2025|  West|       Furniture|        165|Delhi| 31|       Basic|  165|    S101|user1014@gmail.com|user1014|Completed|14-01-2025 10:13|
# |   1015|      15-01-2025|  West|        Clothing|        170|Delhi| 32|     Premium|  170|    S101|user1015@gmail.com|user1015|Completed|15-01-2025 10:14|
# |   1016|      16-01-2025|  West|         Grocery|        175|Delhi| 33|       Basic|  175|    S101|user1016@gmail.com|user1016|Completed|16-01-2025 10:15|
# |   1017|      17-01-2025|  West|     Electronics|        180|Delhi| 34|     Premium|  180|    S101|user1017@gmail.com|user1017|Completed|17-01-2025 10:16|
# |   1018|      18-01-2025|  West|       Furniture|        185|Delhi| 35|       Basic| NULL|    S101|user1018@gmail.com|user1018|Completed|18-01-2025 10:17|
# |   1019|      19-01-2025|  West|        Clothing|        190|Delhi| 18|     Premium|  190|    S101|user1019@gmail.com|user1019|Completed|19-01-2025 10:18|
# |   1020|      20-01-2025|  West|         Grocery|        195|Delhi| 19|       Basic|  195|    S101|              NULL|user1020|Completed|20-01-2025 10:19|
# +-------+----------------+------+----------------+-----------+-----+---+------------+-----+--------+------------------+--------+---------+----------------+
# only showing top 20 rows

# %%
df.printSchema()
# Out:
# root
#  |-- user_id: integer (nullable = true)
#  |-- transaction_date: string (nullable = true)
#  |-- region: string (nullable = true)
#  |-- product_category: string (nullable = true)
#  |-- sale_amount: integer (nullable = true)
#  |-- city: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- subscription: string (nullable = true)
#  |-- price: integer (nullable = true)
#  |-- store_id: string (nullable = true)
#  |-- email: string (nullable = true)
#  |-- username: string (nullable = true)
#  |-- status: string (nullable = true)
#  |-- raw_timestamp: string (nullable = true)

# %%
df.count()
# Out:
# 401

# %%
# Q5: Given a DataFrame df, write a query to select the columns product_id and price where the category is 'Electronics'.
from pyspark.sql.functions import col

selected_df = df.filter(col("product_category") == "Electronics") \
                .select("user_id", "price")

selected_df.show()
# Out:
# +-------+-----+
# |user_id|price|
# +-------+-----+
# |   1001| NULL|
# |   1005|  120|
# |   1009|  140|
# |   1013|  160|
# |   1017|  180|
# |   1021|  200|
# |   1025|  220|
# |   1029|  240|
# |   1033|  260|
# |   1037|  280|
# |   1041|  300|
# |   1045|  320|
# |   1049|  340|
# |   1053|  360|
# |   1057|  380|
# |   1061|  400|
# |   1065|  420|
# |   1069| NULL|
# |   1073|  460|
# |   1077|  480|
# +-------+-----+
# only showing top 20 rows

# %%
# Q6: Write the code to "revise" a DataFrame by renaming the column old_name to new_name and casting the price column from a String to a Double.
from pyspark.sql.functions import col

df = df.withColumnRenamed("old_name", "new_name")

df = df.withColumn(
    "price",
    col("price").cast("double")
)
df.show()
# Out:
# +-------+----------------+------+----------------+-----------+-----+---+------------+-----+--------+------------------+--------+---------+----------------+
# |user_id|transaction_date|region|product_category|sale_amount| city|age|subscription|price|store_id|             email|username|   status|   raw_timestamp|
# +-------+----------------+------+----------------+-----------+-----+---+------------+-----+--------+------------------+--------+---------+----------------+
# |   1001|      01-01-2025|  West|     Electronics|        100|Delhi| 18|     Premium| NULL|    S101|              NULL|    NULL|     NULL|01-01-2025 10:00|
# |   1002|      02-01-2025|  West|       Furniture|        105|Delhi| 19|       Basic|105.0|    S101|user1002@gmail.com|user1002|Completed|02-01-2025 10:01|
# |   1003|      03-01-2025|  West|        Clothing|        110|Delhi| 20|     Premium|110.0|    S101|user1003@gmail.com|user1003|Completed|03-01-2025 10:02|
# |   1004|      04-01-2025|  West|         Grocery|        115|Delhi| 21|       Basic|115.0|    S101|user1004@gmail.com|user1004|Completed|04-01-2025 10:03|
# |   1005|      05-01-2025|  West|     Electronics|        120|Delhi| 22|     Premium|120.0|    S101|user1005@gmail.com|user1005|Completed|05-01-2025 10:04|
# |   1006|      06-01-2025|  West|       Furniture|        125|Delhi| 23|       Basic|125.0|    S101|user1006@gmail.com|user1006|Completed|06-01-2025 10:05|
# |   1007|      07-01-2025|  West|        Clothing|        130|Delhi| 24|     Premium|130.0|    S101|user1007@gmail.com|user1007|Completed|07-01-2025 10:06|
# |   1008|      08-01-2025|  West|         Grocery|        135|Delhi| 25|       Basic|135.0|    S101|user1008@gmail.com|user1008|Completed|08-01-2025 10:07|
# |   1009|      09-01-2025|  West|     Electronics|        140|Delhi| 26|     Premium|140.0|    S101|user1009@gmail.com|user1009|Completed|09-01-2025 10:08|
# |   1010|      10-01-2025|  West|       Furniture|        145|Delhi| 27|       Basic|145.0|    S101|user1010@gmail.com|user1010|Completed|10-01-2025 10:09|
# |   1011|      11-01-2025|  West|        Clothing|        150|Delhi| 28|     Premium|150.0|    S101|user1011@gmail.com|user1011|Completed|11-01-2025 10:10|
# |   1012|      12-01-2025|  West|         Grocery|        155|Delhi| 29|       Basic|155.0|    S101|user1012@gmail.com|user1012|Completed|12-01-2025 10:11|
# |   1013|      13-01-2025|  West|     Electronics|        160|Delhi| 30|     Premium|160.0|    S101|user1013@gmail.com|user1013|Completed|13-01-2025 10:12|
# |   1014|      14-01-2025|  West|       Furniture|        165|Delhi| 31|       Basic|165.0|    S101|user1014@gmail.com|user1014|Completed|14-01-2025 10:13|
# |   1015|      15-01-2025|  West|        Clothing|        170|Delhi| 32|     Premium|170.0|    S101|user1015@gmail.com|user1015|Completed|15-01-2025 10:14|
# |   1016|      16-01-2025|  West|         Grocery|        175|Delhi| 33|       Basic|175.0|    S101|user1016@gmail.com|user1016|Completed|16-01-2025 10:15|
# |   1017|      17-01-2025|  West|     Electronics|        180|Delhi| 34|     Premium|180.0|    S101|user1017@gmail.com|user1017|Completed|17-01-2025 10:16|
# |   1018|      18-01-2025|  West|       Furniture|        185|Delhi| 35|       Basic| NULL|    S101|user1018@gmail.com|user1018|Completed|18-01-2025 10:17|
# |   1019|      19-01-2025|  West|        Clothing|        190|Delhi| 18|     Premium|190.0|    S101|user1019@gmail.com|user1019|Completed|19-01-2025 10:18|
# |   1020|      20-01-2025|  West|         Grocery|        195|Delhi| 19|       Basic|195.0|    S101|              NULL|user1020|Completed|20-01-2025 10:19|
# +-------+----------------+------+----------------+-----------+-----+---+------------+-----+--------+------------------+--------+---------+----------------+
# only showing top 20 rows
